# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# 실행할 때마다 같은 결과를 출력하기 위해 설정하는 부분입니다.
np.random.seed(3)
tf.random.set_seed(3)

# 데이터 입력
df = pd.read_csv('./dataset/iris.csv', names = ["sepal_length", "sepal_width", "petal_length", "petal_width", "species"])

print(df.info())
print(df.head())


# 데이터 분류
dataset = df.values
X = dataset[:,0:4].astype(float)
Y_obj = dataset[:,4]

# 문자열을 숫자로 변환
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)
Y_encoded = tf.keras.utils.to_categorical(Y)

# 모델의 설정
model = Sequential()
model.add(Dense(16,  input_dim=4, activation='relu'))
model.add(Dense(3, activation='softmax'))

# 모델 컴파일
model.compile(loss='categorical_crossentropy',
            optimizer='adam',
            metrics=['accuracy'])

X_data = X[:5, :]
Y_data = Y_encoded[:5, :]

model.fit(X_data, Y_data, epochs=50, batch_size=1, verbose=0)
Y_prediction= model.predict(X_data)
predict = np.array(Y_prediction)

name = Y_obj[:5]
name = np.array(Y_obj)

for i in range(5):
    print('Prediction output: ' + str(predict[i]))
    max = np.argmax(predict[i])
    print('Selected area: ' + str(max))
    print('Actual: ' + str(name[i]) + ', Prediction: ' + str(name[max]))
